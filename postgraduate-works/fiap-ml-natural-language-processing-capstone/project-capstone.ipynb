# %% [markdown]
# # Projeto de *Processamento de Linguagem Natural*
#
# ## Introdução & Proposta
#
# A seguinte proposta de solução tem por finalidade resolver o desafio levantado a partir do seguinte enunciado de projeto-problema proposto:
#
# > Utilizando o dataset de revisões de filmes em português (baixado com ajuda do código abaixo), criar um classificador de sentimentos que consiga um score na métrica **F1 Score** superior a 70%.
# >
# > Fique a vontade para testar métodos de pré-processamento, abordagens, algoritmos e bibliotecas, mas explique e justifique suas decisões.
# >
# > O trabalho poderá ser feito em grupo (mesmos grupos do Startup One).
# >
# > A data de entrega é dia 15/02/2019 até as 23:59 horas.
#
# A base de dados disponibilizada é constituída por comentários do IMDb em língua portuguesa. O modelo baseado em Naives Bayes foi escolhido para a realização de predição de sentimento (análise de sentimento), o qual permitiu a obtenção de resultados significativos (F1 Score superior a 70%).
#
# O modelo Naive Bayes tem sido utilizado para esta finalidade por atribuir pesos às palavras presentes no texto e conseguir correlacionar o peso destas para a classe de dados do problema – neste caso, dividida em `"neg"` e `"pos"`; respectivamente, negativo e positivo. De início testamos o modelo Naive Bayes sem a remoção de léxicos dos textos (como *stopwords*); em seguida, testamos o modelo com a remoção destes léxicos. A partir dos resultados obtidos, podemos constatar que não houve ganhos significativos a partir destas duas abordagens de preparação da base de dados.
#
# ## Autores da solução proposta
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------ | :---: |
# | Alexandre Lima Freitas   | RM 330376     | `1IA` |
# | Ewerton Carlos Assis     | RM 330737     | `1IA` |
# | Felipe Ribeiro da Silva  | RM 330332     | `1IA` |

# %% [markdown]
# ## Obtenção da base de dados

# %% [markdown]
# A classe a seguir nos ajudará a acompanhar o progresso do download.

# %%
import tqdm
from tqdm import tqdm

class DLProgress(tqdm):
  last_block = 0

  def hook(self, block_num=1, block_size=1, total_size=None):
    self.total = total_size
    self.update((block_num - self.last_block) * block_size)
    self.last_block = block_num

# %% [markdown]
# O código a seguir fará o download do arquivo compactado do dataset e descompactará o mesmo. Em seguida, é feita a assertiva da obtenção da base dados em arquivo `csv`.

# %%
from urllib.request import urlretrieve
from os.path import isfile
import zipfile

path = "content/imdb-pt-br.zip"
url = "https://drive.google.com/uc?export=download&id=1Jz3H23oBy3yDf8ARQsflwRX-EFX7HKqM"

if not isfile(path):
  with DLProgress(unit="B", unit_scale=True, miniters=1, desc="IMDB") as pbar:
    urlretrieve(
      url,
      path,
      pbar.hook)

if not isfile("content/reviews/imdb-review-pt-br.csv"):     
  zip_ref = zipfile.ZipFile(path, "r")
  zip_ref.extractall("content/reviews")
  zip_ref.close()
# Out:
# IMDB: 50.0MB [00:14, 3.41MB/s]

# %%
# !ls -all -h content/reviews/imdb-reviews-pt-br.csv
# Out:
# -rw-r--r-- 1 earaujoassis staff 122M Aug  4 17:23 content/reviews/imdb-reviews-pt-br.csv

# %% [markdown]
# ## Definições comuns aos modelos de análise

# %%
import numpy as np
import pandas as pd
import nltk
import re
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import cross_val_predict
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize
from wordcloud import WordCloud

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_master = pd.read_csv("content/reviews/imdb-reviews-pt-br.csv", encoding="utf-8", index_col=0)

# %%
list(df_master.columns.values)
# Out:
# ['text_en', 'text_pt', 'sentiment']

# %%
df_master[["text_pt", "sentiment"]]
# Out:
#                                                  text_pt sentiment
# id
# 1      Mais uma vez, o Sr. Costner arrumou um filme p...       neg
# 2      Este é um exemplo do motivo pelo qual a maiori...       neg
# 3      Primeiro de tudo eu odeio esses raps imbecis, ...       neg
# 4      Nem mesmo os Beatles puderam escrever músicas ...       neg
# 5      Filmes de fotos de latão não é uma palavra apr...       neg
# 6      Uma coisa engraçada aconteceu comigo enquanto ...       neg
# 7      Este filme de terror alemão tem que ser um dos...       neg
# 8      Sendo um fã de longa data do cinema japonês, e...       neg
# 9      "Tokyo Eyes" fala de uma menina japonesa de 17...       neg
# 10     Fazendeiros ricos em Buenos Aires têm uma long...       neg
# 11     Cage interpreta um bêbado e é elogiado pela cr...       neg
# 12     Primeiro de tudo, eu gostaria de dizer que sou...       neg
# 13     Então me diga - que boozer sério bebe a Budwei...       neg
# 14     Uma grande decepção para o que foi apresentado...       neg
# 15     Este filme é absolutamente terrível e horrível...       neg
# 16     Heres um decididamente médio post italiano apo...       neg
# 17     Na parte inferior da escala de filmes do apoca...       neg
# 18     A terra foi destruída em um holocausto nuclear...       neg
# 19     Muitas pessoas estão em pé na frente da casa n...       neg
# 20     A família de Nova York é a última em seu bairr...       neg
# 21     A melhor coisa sobre "The Prey" é o slogan ......       neg
# 22     Isto é verdadeiramente, sem exagerar, um dos p...       neg
# 23     Sou um grande fã de Emily Watson, Breaking The...       neg
# 24     Claro, a maioria dos filmes de terror da décad...       neg
# 25     Eu acho que teria sido um título mais apropria...       neg
# 26     1980 foi certamente um ano para maus filmes de...       neg
# 27     Tudo o que todo mundo já disse é verdade quand...       neg
# 28     Uhhh ... então, eles ainda têm escritores para...       neg
# 29     Ah, sim, este é definitivamente um forte candi...       neg
# 30     Receita de slash supercraptástico, que parece ...       neg
# ...                                                  ...       ...
# 49431  não é tão bom quanto o primeiro filme, mas é u...       pos
# 49432  Claro, era brega e sem sentido e às vezes breg...       pos
# 49433  SPOILERS ATRAVÉS: Eu realmente estou em minori...       pos
# 49434  Eu tenho que dizer, eu amei Vanishing Point. E...       pos
# 49435  Para começar, já que este filme é um remake de...       pos
# 49436  Eu tenho que concordar com a maioria dos outro...       pos
# 49437  Qualquer filme que mostre que os PIGs federais...       pos
# 49438  No diretor canadense Kari Skoglands, adaptação...       pos
# 49439  Eu vi este filme ontem à noite depois de esper...       pos
# 49440  Este filme é basicamente sobre relações humana...       pos
# 49441  Fiquei surpreso com o quanto eu gostei deste d...       pos
# 49442  Eu vi este filme em Winnipeg recentemente - ap...       pos
# 49443  Como talvez um dos poucos canadenses que não l...       pos
# 49444  Fiquei muito comovido com a história e porque ...       pos
# 49445  O que eu amei na adaptação para a tela de The ...       pos
# 49446  Eu tive a chance de ver uma exibição desse fil...       pos
# 49447  Este é um filme muito interessante. É um filme...       pos
# 49448  Eu vi o filme recentemente e realmente gostei....       pos
# 49449  Eu pensei que esse filme fosse histérico. Eu a...       pos
# 49450  ... este é um clássico com tantos grandes diál...       pos
# 49451  O mais hillarious e engraçado filme de Brooks ...       pos
# 49452  "A vida cheira mal" é uma paródia de vida e mo...       pos
# 49453  Este é o tipo de filme que você quer ver com u...       pos
# 49454  Eu não li os outros comentários sobre o filme,...       pos
# 49455  Life Stinks 1991 foi um passo abaixo de outras...       pos
# 49456  Como a média de votos era muito baixa, e o fat...       pos
# 49457  O enredo teve algumas reviravoltas infelizes e...       pos
# 49458  Estou espantado com a forma como este filme e ...       pos
# 49459  A Christmas Together realmente veio antes do m...       pos
# 49460  O drama romântico da classe trabalhadora do di...       pos
#
# [49459 rows x 2 columns]

# %%
number_rows = df_master.shape[0]
traninng_threshold = int(0.40 * number_rows)

# %%
training_df = df_master[["text_pt", "sentiment"]].iloc[0:traninng_threshold]
testing_df = df_master[["text_pt", "sentiment"]].iloc[traninng_threshold + 1:-1]

# %%
training_df
# Out:
#                                                  text_pt sentiment
# id
# 1      Mais uma vez, o Sr. Costner arrumou um filme p...       neg
# 2      Este é um exemplo do motivo pelo qual a maiori...       neg
# 3      Primeiro de tudo eu odeio esses raps imbecis, ...       neg
# 4      Nem mesmo os Beatles puderam escrever músicas ...       neg
# 5      Filmes de fotos de latão não é uma palavra apr...       neg
# 6      Uma coisa engraçada aconteceu comigo enquanto ...       neg
# 7      Este filme de terror alemão tem que ser um dos...       neg
# 8      Sendo um fã de longa data do cinema japonês, e...       neg
# 9      "Tokyo Eyes" fala de uma menina japonesa de 17...       neg
# 10     Fazendeiros ricos em Buenos Aires têm uma long...       neg
# 11     Cage interpreta um bêbado e é elogiado pela cr...       neg
# 12     Primeiro de tudo, eu gostaria de dizer que sou...       neg
# 13     Então me diga - que boozer sério bebe a Budwei...       neg
# 14     Uma grande decepção para o que foi apresentado...       neg
# 15     Este filme é absolutamente terrível e horrível...       neg
# 16     Heres um decididamente médio post italiano apo...       neg
# 17     Na parte inferior da escala de filmes do apoca...       neg
# 18     A terra foi destruída em um holocausto nuclear...       neg
# 19     Muitas pessoas estão em pé na frente da casa n...       neg
# 20     A família de Nova York é a última em seu bairr...       neg
# 21     A melhor coisa sobre "The Prey" é o slogan ......       neg
# 22     Isto é verdadeiramente, sem exagerar, um dos p...       neg
# 23     Sou um grande fã de Emily Watson, Breaking The...       neg
# 24     Claro, a maioria dos filmes de terror da décad...       neg
# 25     Eu acho que teria sido um título mais apropria...       neg
# 26     1980 foi certamente um ano para maus filmes de...       neg
# 27     Tudo o que todo mundo já disse é verdade quand...       neg
# 28     Uhhh ... então, eles ainda têm escritores para...       neg
# 29     Ah, sim, este é definitivamente um forte candi...       neg
# 30     Receita de slash supercraptástico, que parece ...       neg
# ...                                                  ...       ...
# 19755  Conto cativante de backstabbing atrás das cort...       pos
# 19756  Acabei de voltar de Santa Fé. NM Eu visitei a ...       pos
# 19757  Excelente história com supperb atuando por tod...       pos
# 19758  Eu vi esse filme quando ele foi ao ar na Lifet...       pos
# 19759  Eu não vi isso desde 1998 e ainda assim eu não...       pos
# 19760  Quase nenhuma informação está disponível sobre...       pos
# 19761  Este filme é sobre uma mãe solteira que é feli...       pos
# 19762  E eu teria avaliado acima de 7 de 10 se não fo...       pos
# 19763  Eu sou do Texas e minha família esteve de féri...       pos
# 19764  Para aqueles de vocês que já fizeram comentári...       pos
# 19765  Sério, qualquer filme com John Malkovich é ger...       pos
# 19766  Wolfgang Petersen Das Boot, o Air Force One no...       pos
# 19767  Wolfgang Peterson dirige este thriller que Cli...       pos
# 19768  O que eu vi dos filmes de Wolfgang Petersens f...       pos
# 19769  Este é um dos poucos filmes deste tipo que rev...       pos
# 19770  Este é um filme de Hollywood. As credenciais d...       pos
# 19771  Esse é o excelente thriller de Washington diri...       pos
# 19772  A principal atração de Anywhere, mas aqui é o ...       pos
# 19773  Um thriller de assassinato nos moldes de Day O...       pos
# 19774  Eu realmente amo filmes de ação / aventura e e...       pos
# 19775  Frank Horrigan Clint Eastwood está sendo assed...       pos
# 19776  "Na Linha de Fogo" é um dos melhores thrillers...       pos
# 19777  Acabei de ver este filme pela primeira vez na ...       pos
# 19778  Eu sou um grande fã de filmes de ação grandes,...       pos
# 19779  Em The Line Of Fire conta a história do jogo e...       pos
# 19780  Quando eu estava trabalhando, lembro-me de ter...       pos
# 19781  Aqui está outro divertido filme de ação-suspen...       pos
# 19782  Wolfgang Petersons Na Linha de Fogo é astúcia ...       pos
# 19783  Anne Natalie Portman fala sobre o quanto ela o...       pos
# 19784  Eu estava assistindo a Tempestade Perfeita e p...       pos
#
# [19783 rows x 2 columns]

# %%
testing_df
# Out:
#                                                  text_pt sentiment
# id
# 19786  Um dos melhores filmes que eu já vi ... Bom ro...       pos
# 19787  NA LINHA DE FOGO, na minha opinião, é um excel...       pos
# 19788  Este é outro dos muitos filmes de Eastwood que...       pos
# 19789  Um ótimo desempenho de Clint Eastwood e partic...       pos
# 19790  Frank Horrigan Clint Eastwood é um agente do s...       pos
# 19791  Clint Eastwood é um grande sucesso neste thril...       pos
# 19792  Muito simplesmente um filme bem escrito, bem e...       pos
# 19793  Na linha de fogo nos dá um grande jogo de gato...       pos
# 19794  Eu pude ver "Anywhere But Here" ontem à noite ...       pos
# 19795  Este filme foi ótimo. Algo não apenas para o m...       pos
# 19796  In the Line of Fire é um daqueles filmes de Ho...       pos
# 19797  Escrito pelos brilhantes roteiristas da TV Mon...       pos
# 19798  Por alguma razão inexplicável, os filmes de Je...       pos
# 19799  Um filme muito diferente de Jerry Lewis, não c...       pos
# 19800  Eu acho que esse filme é o filme mais incompre...       pos
# 19801  Um homem doente, Carleton Hendricks Dee Snider...       pos
# 19802  muitas pessoas disseram que este filme não era...       pos
# 19803  Este filme de terror off-beat parece estar rec...       pos
# 19804  Todo mundo me disse que este filme não era bom...       pos
# 19805  Eu não entendo de onde esses comentários ruins...       pos
# 19806  Meu resumo de uma linha sugere que esse não é ...       pos
# 19807  Este thriller é uma das poucas surpresas de fi...       pos
# 19808  Eu realmente não acho que esse filme foi ruim....       pos
# 19809  Dee Snider foi inspirado a fazer uma música de...       pos
# 19810  Honestamente, este é um dos melhores filmes de...       pos
# 19811  Strangeland parece ter uma relação de amor / ó...       pos
# 19812  Muitas pessoas dão a este filme muita porcaria...       pos
# 19813  Andrew McCarthy desempenhou o papel de um ateu...       pos
# 19814  Eu gostei do filme, e o fato de que ele aponto...       pos
# 19815  Este filme foi diferente. Levou uma espécie de...       pos
# ...                                                  ...       ...
# 49430  Claro que este foi um remake de um filme dos a...       pos
# 49431  não é tão bom quanto o primeiro filme, mas é u...       pos
# 49432  Claro, era brega e sem sentido e às vezes breg...       pos
# 49433  SPOILERS ATRAVÉS: Eu realmente estou em minori...       pos
# 49434  Eu tenho que dizer, eu amei Vanishing Point. E...       pos
# 49435  Para começar, já que este filme é um remake de...       pos
# 49436  Eu tenho que concordar com a maioria dos outro...       pos
# 49437  Qualquer filme que mostre que os PIGs federais...       pos
# 49438  No diretor canadense Kari Skoglands, adaptação...       pos
# 49439  Eu vi este filme ontem à noite depois de esper...       pos
# 49440  Este filme é basicamente sobre relações humana...       pos
# 49441  Fiquei surpreso com o quanto eu gostei deste d...       pos
# 49442  Eu vi este filme em Winnipeg recentemente - ap...       pos
# 49443  Como talvez um dos poucos canadenses que não l...       pos
# 49444  Fiquei muito comovido com a história e porque ...       pos
# 49445  O que eu amei na adaptação para a tela de The ...       pos
# 49446  Eu tive a chance de ver uma exibição desse fil...       pos
# 49447  Este é um filme muito interessante. É um filme...       pos
# 49448  Eu vi o filme recentemente e realmente gostei....       pos
# 49449  Eu pensei que esse filme fosse histérico. Eu a...       pos
# 49450  ... este é um clássico com tantos grandes diál...       pos
# 49451  O mais hillarious e engraçado filme de Brooks ...       pos
# 49452  "A vida cheira mal" é uma paródia de vida e mo...       pos
# 49453  Este é o tipo de filme que você quer ver com u...       pos
# 49454  Eu não li os outros comentários sobre o filme,...       pos
# 49455  Life Stinks 1991 foi um passo abaixo de outras...       pos
# 49456  Como a média de votos era muito baixa, e o fat...       pos
# 49457  O enredo teve algumas reviravoltas infelizes e...       pos
# 49458  Estou espantado com a forma como este filme e ...       pos
# 49459  A Christmas Together realmente veio antes do m...       pos
#
# [29674 rows x 2 columns]

# %% [markdown]
# ## Naive Bayes: preparação, treinamento & análise dos dados para solução simples

# %% [markdown]
# Nesta solução, o modelo baseado em Naive Bayes é utilizado sem qualquer remoção de palavras ou tratamento específico para a base de dados. Ainda assim, obtemos um valor de F1 Score significativo.

# %%
training_docs = training_df["text_pt"].values
training_classes = training_df["sentiment"].values
testing_docs = testing_df["text_pt"].values

# %%
vectorizer = CountVectorizer(analyzer="word")
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = MultinomialNB()
model.fit(frequency_training_docs, training_classes)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['pos', 'pos', 'pos', ..., 'pos', 'neg', 'pos'], dtype='<U3')

# %% [markdown]
# ### Análise dos resultados a partir do modelo em Naive Bayes

# %%
y_true = testing_df["sentiment"].values
y_pred = testing_classes

# %%
f1_score(y_true, y_pred, average=None)
# Out:
# array([0.75941697, 0.75888128])

# %% [markdown]
# ## Naive Bayes: preparação, treinamento & análise dos dados com remoção de *stopwords*

# %%
def remove_stopwords_and_punctuation(docs):
    stop_words = set(stopwords.words("portuguese"))
    neo_docs = []

    for sentence in docs:
        cleanr = re.compile('<.*?>')
        sentence = re.sub(r'\d+', '', sentence)
        sentence = re.sub(cleanr, '', sentence)
        sentence = re.sub("'", '', sentence)
        sentence = re.sub(r'\W+', ' ', sentence)
        sentence = sentence.replace('_', '')
        sentence = [word for word in sentence.lower().split() if word not in stop_words]
        sentence = ' '.join(sentence)
        neo_docs.append(sentence)

    return neo_docs

# %%
training_docs = remove_stopwords_and_punctuation(training_df["text_pt"].values)
training_classes = training_df["sentiment"].values
testing_docs = remove_stopwords_and_punctuation(testing_df["text_pt"].values)

# %%
vectorizer = CountVectorizer(analyzer="word")
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = MultinomialNB()
model.fit(frequency_training_docs, training_classes)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['pos', 'pos', 'pos', ..., 'pos', 'neg', 'pos'], dtype='<U3')

# %%
y_true = testing_df["sentiment"].values
y_pred = testing_classes

# %%
f1_score(y_true, y_pred, average=None)
# Out:
# array([0.76341975, 0.76545198])

# %% [markdown]
# ## Comparativo das soluções

# %% [markdown]
# Ainda que os resultados apresentados pela segunda abordagem, com remoção das *stopwords*, tenha sido de maior qualidade no valor F1 Score, o ganho obtido não foi significativo: o valor de aumento em 1,3% pode ser afirmado como insignificante.
#
# A solução proposta neste projeto baseia-se na comparação de métodos de preparação da base de dados para aplicação no modelo de solução. No caso do modelo baseado em Naive Bayes, a solução proposta consegue balancear e equilibrar a importância e o valor-peso das *stopwords* nas frases/sentenças analisadas. Assim, as *stopwords*, no caso desta solução baseada em Naive Bayes, não geram peso significante na qualidade da solução proposta.
