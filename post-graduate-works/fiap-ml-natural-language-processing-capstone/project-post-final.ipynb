# %% [markdown]
# # Projeto de *Processamento de Linguagem Natural*
#
# Atividade substitutiva da disciplina de *Processamento de Linguagem Natural*

# %% [markdown]
# ## Obtenção da base de dados

# %%
# !ls -all -h data/produtos.csv
# Out:
# -rw-r--r-- 1 earaujoassis staff 3.7M Aug  4 16:08 data/produtos.csv

# %% [markdown]
# ## Definições comuns aos modelos de análise

# %%
import numpy as np
import pandas as pd
import nltk
import re
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split

from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize
from wordcloud import WordCloud

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_master = pd.read_csv("data/produtos.csv", encoding="utf-8", index_col=0, sep=';')

# %%
list(df_master.head())
# Out:
# ['descricao', 'categoria']

# %%
df_master[['descricao', 'categoria']]
# Out:
#                                                                                             descricao  \
# nome
#  O Hobbit - 7ª Ed. 2013                             Produto NovoBilbo Bolseiro é um hobbit que lev...
#  Livro - It A Coisa - Stephen King                  Produto NovoDurante as férias escolares de 195...
#  Box  As Crônicas De Gelo E Fogo  Pocket  5 Liv...  Produto NovoTodo o reino de Westeros ao alcanc...
#  Box Harry Potter                                   Produto Novo e Físico  A série Harry Potter ch...
#  Livro Origem - Dan Brown                           Produto NovoDe Onde Viemos? Para Onde Vamos? R...
#  Mais Escuro - Cinquenta Tons Mais Escuros Pelo...  Produto Novo e Físico  O relacionamento quente...
#  O Silmarillion - 5ª Ed. 2011                       Produto NovoO Silmarillion, relata acontecimen...
#  O Pequeno Principe                                 O Pequeno Príncipe é um dos personagens mais f...
#  Ed & Lorraine Warren - Demonologistas  Arquivo...  Produto NovoEles enfrentaram os mistérios mais...
#  Box - Franz Kafka 1883-1924 - 3 Livros             Produto NovoEste box contém 3 livros de Franz ...
#  Livros The Walking Dead-envio Imediato- Promoç...  MATERIAL DIGITAL Coleção de 04 livros, são os ...
#  Livro - Coleção Harry Potter (7 Volumes) - Lac...                                                NaN
#  It - A Coisa                                       Produto Novo e Físico  Durante as férias escol...
#  Bibliocanto Organizador Separador De Livros        BIBLIOCANTO """"""preço em promoçao!!!! tempo ...
#  Gravity Falls Journal 3                            Produto Novo e Físico  Journal 3 brims with ev...
#  Nutri Ninja Auto Iq + Livro 220v                   Sabe-se que uma alimentação saudável consiste ...
#  Outros Jeitos De Usar A Boca                       Produto NovoOutros jeitos de usar a boca é um ...
#  Caixa De Pássaros                                  Produto NovoRomance de estreia de Josh Malerma...
#  Extraordinario                                     Produto Novo e Físico  August Pullman, o Auggi...
#  Box - Irmãos Maddox - 5 Livros  Edição Econômica   Produto NovoO fenômeno de Belo Desastre contin...
#  Uma Pergunta Por Dia                               Produto NovoTodos os dias criamos uma imensa q...
#  Tartarugas Até Lá Embaixo                          Produto NovoDepois de seis anos, milhões de li...
#  Admirável Mundo Novo                               Produto NovoUma sociedade inteiramente organiz...
#  Box A Garota Do Calendário Novo No Plástico Fr...  ATENÇÃO!PARA OBTER O FRETE GRÁTIS, SELECIONAR ...
#  Supernatural - O Diario De John Winchester - G...  O diário de John Winchester é a peça-chave par...
#  Kit - Stephen King - Trilogia Bill Hodges - 3 ...  Produto NovoEste kit contém 3 livros da Trilog...
#  Caixa De Passaros                                  Basta uma olhadela para desencadear um impulso...
#  O Homem Mais Inteligente Da Historia               Produto Novo e Físico  O Homem Mais Inteligent...
#  Depois De Você                                     Produto NovoQuando uma história termina, outra...
#  Quem É Você, Alasca? - O Primeiro Amigo, A Pri...                                                NaN
# ...                                                                                               ...
#  Assassins Creed 4 Black Flag - Ps3 - Português...                                                NaN
#  Pes 2018 | Pro Evolution Soccer 18 | Ps3 | Psn...                                                NaN
#  100.000 Coins Fifa 18 Ps3 Ultimate Team - Play...                                                NaN
#  Dragon Ball Xenoverse Português Mídia Física X...                                                NaN
#  Far Cry 4 Pt-br Ps3 Psn Midia Digital              ATENÇÃO: Produto Digital. Não EFETUE PAGAMENTO...
#  Fifa 18 Ps3 Completo Dublado Em Português - Mí...                                                NaN
#  Cs-go Skin - Galil Ar | Pipocolé ( Testada Em ...                                                NaN
#  J-stars Victory Vs+ Ps3 Legenda Português  Psn                                                   NaN
#  Point Blank Ongame - Cartão De 10.000 Cash - E...                                                NaN
#  Kit Capa Para Jogos Do Ps4                         Kit Capa para jogos do PlayStation 4Temos dive...
#  Fifa Street Ps3 Psn Digital Envio Imediato         Nome do jogo: FIFA StreetConsole: Playstation ...
#  Assassin's Creed The Ezio Collection Xbox One ...  Você esta comprando na JXGAMESASSASSIN´S CREED...
#  Rocksmith 2014 Remaste Xbox One Jogo + Cabo + ...                                                NaN
#  Pes 17 Pro Evolution 2017 Ps3 Psn Envio Digita...                                                NaN
#  Bandfuse: Rock Legends (game + Cabo) - Xbox 36...  ---SAMAVI SHOP--- Veja todos os nossos produto...
#  Resident Evil 5 Gold Edition Ps3 Psn Midia Dig...                                                NaN
#  Dead Space 3 - Ps3 - Código Psn - Promoção !!                                                    NaN
#  Resident Evil 5 Gold Edition - Ps3 - Psn - Env...                                                NaN
#  Ea Sports Fifa 16 - Ps3 - Psn - Dub Português ...                                                NaN
#  Just Dance 2017 Ps3 Código Psn Português Envio...                                                NaN
#  Lego Jurassic World | Ps3 Mídia Digital Portug...  LEGO© Jurassic World™TAMANHO DO ARQUIVO5.8 GBP...
#  Far Cry 4 Ps3  Psn Português                                                                     NaN
#  Pes 2017 (pc) Dublado Em Português Original Fr...                                                NaN
#  Red Dead Redemption Edição Do Ano Goty Xbox 36...  Red Dead Redemption Edição Do Ano Goty Xbox 36...
#  Jogo Gta 5 Grand Theft Auto V Ps4 Mídia Cd + M...  Game: GTA V - Grand Theft Auto FiveEspecificaç...
#  Zelda: Breath Of The Wild - Expansion Pass - D...  ENVIO IMEDIATO APÓS CONFIRMAÇÃOCom este Passe ...
#  Middle Earth Shadow Of Mordor Legion Edition P...                                                NaN
#  Fifa 17 Ps3 Dublado Em Pt Br Envio Digital Ime...                                                NaN
#  Gta San Andreas Hd Remastered Ps3 Envio Imediato   Nome do jogo: GTA San Andreas HD RemasterConso...
#  Mini Game  Nova Portátil 10mil Jogos Player Mp...  Para ligar o aparelho pressionar os botões On ...
#
#                                                    categoria
# nome
#  O Hobbit - 7ª Ed. 2013                                livro
#  Livro - It A Coisa - Stephen King                     livro
#  Box  As Crônicas De Gelo E Fogo  Pocket  5 Liv...     livro
#  Box Harry Potter                                      livro
#  Livro Origem - Dan Brown                              livro
#  Mais Escuro - Cinquenta Tons Mais Escuros Pelo...     livro
#  O Silmarillion - 5ª Ed. 2011                          livro
#  O Pequeno Principe                                    livro
#  Ed & Lorraine Warren - Demonologistas  Arquivo...     livro
#  Box - Franz Kafka 1883-1924 - 3 Livros                livro
#  Livros The Walking Dead-envio Imediato- Promoç...     livro
#  Livro - Coleção Harry Potter (7 Volumes) - Lac...     livro
#  It - A Coisa                                          livro
#  Bibliocanto Organizador Separador De Livros           livro
#  Gravity Falls Journal 3                               livro
#  Nutri Ninja Auto Iq + Livro 220v                      livro
#  Outros Jeitos De Usar A Boca                          livro
#  Caixa De Pássaros                                     livro
#  Extraordinario                                        livro
#  Box - Irmãos Maddox - 5 Livros  Edição Econômica      livro
#  Uma Pergunta Por Dia                                  livro
#  Tartarugas Até Lá Embaixo                             livro
#  Admirável Mundo Novo                                  livro
#  Box A Garota Do Calendário Novo No Plástico Fr...     livro
#  Supernatural - O Diario De John Winchester - G...     livro
#  Kit - Stephen King - Trilogia Bill Hodges - 3 ...     livro
#  Caixa De Passaros                                     livro
#  O Homem Mais Inteligente Da Historia                  livro
#  Depois De Você                                        livro
#  Quem É Você, Alasca? - O Primeiro Amigo, A Pri...     livro
# ...                                                      ...
#  Assassins Creed 4 Black Flag - Ps3 - Português...      game
#  Pes 2018 | Pro Evolution Soccer 18 | Ps3 | Psn...      game
#  100.000 Coins Fifa 18 Ps3 Ultimate Team - Play...      game
#  Dragon Ball Xenoverse Português Mídia Física X...      game
#  Far Cry 4 Pt-br Ps3 Psn Midia Digital                  game
#  Fifa 18 Ps3 Completo Dublado Em Português - Mí...      game
#  Cs-go Skin - Galil Ar | Pipocolé ( Testada Em ...      game
#  J-stars Victory Vs+ Ps3 Legenda Português  Psn         game
#  Point Blank Ongame - Cartão De 10.000 Cash - E...      game
#  Kit Capa Para Jogos Do Ps4                             game
#  Fifa Street Ps3 Psn Digital Envio Imediato             game
#  Assassin's Creed The Ezio Collection Xbox One ...      game
#  Rocksmith 2014 Remaste Xbox One Jogo + Cabo + ...      game
#  Pes 17 Pro Evolution 2017 Ps3 Psn Envio Digita...      game
#  Bandfuse: Rock Legends (game + Cabo) - Xbox 36...      game
#  Resident Evil 5 Gold Edition Ps3 Psn Midia Dig...      game
#  Dead Space 3 - Ps3 - Código Psn - Promoção !!          game
#  Resident Evil 5 Gold Edition - Ps3 - Psn - Env...      game
#  Ea Sports Fifa 16 - Ps3 - Psn - Dub Português ...      game
#  Just Dance 2017 Ps3 Código Psn Português Envio...      game
#  Lego Jurassic World | Ps3 Mídia Digital Portug...      game
#  Far Cry 4 Ps3  Psn Português                           game
#  Pes 2017 (pc) Dublado Em Português Original Fr...      game
#  Red Dead Redemption Edição Do Ano Goty Xbox 36...      game
#  Jogo Gta 5 Grand Theft Auto V Ps4 Mídia Cd + M...      game
#  Zelda: Breath Of The Wild - Expansion Pass - D...      game
#  Middle Earth Shadow Of Mordor Legion Edition P...      game
#  Fifa 17 Ps3 Dublado Em Pt Br Envio Digital Ime...      game
#  Gta San Andreas Hd Remastered Ps3 Envio Imediato       game
#  Mini Game  Nova Portátil 10mil Jogos Player Mp...      game
#
# [4080 rows x 2 columns]

# %%
# Shuffle the data frame and its content/rows/entries and
# remove entries with NaN at `categoria` column
df_master = df_master[pd.notnull(df_master['descricao'])]
df_master = df_master.sample(frac=1).reset_index(drop=True)
df_master[['descricao', 'categoria']]
# Out:
#                                               descricao  categoria
# 0     MALETA MAQUIAGEM MACRILAN 53 ITENS!ML2-2MConté...  maquiagem
# 1     KIT 3 PERSONAGENS PJ MASKSTamanho: 22 cmPeso: ...  brinquedo
# 2     As laminas em U são perfeitas para fazer fios ...  maquiagem
# 3     Você esta comprando na G4PLAYLEIA TODA DESCRIÇ...       game
# 4     Itens Inclusos:-01 Anel -01 Mascara-01 Lantern...  brinquedo
# 5     Shadow of the Colossus - PS4 - Mídia Física e ...       game
# 6     ATENÇÃO E-book DIGITAL FORMATO PDF ENVIO PELO ...      livro
# 7     PRODUTO PRONTA ENTREGA NO BRASIL              ...  maquiagem
# 8     Paleta de Sombras Be Besweet HB9923 da Ruby Ro...  maquiagem
# 9     Livro Triste Fim de Policarpo QuaresmaTexto in...      livro
# 10    Produto Novo e Físico  Lançado no Brasil origi...      livro
# 11    Coleção Bonecos Dragon Ball Z Super Articulado...  brinquedo
# 12    Você está comprando com a GCM GAMES*Compre com...       game
# 13    Kit 14 Slugterra Slugterraneo Miniaturas Ataca...  brinquedo
# 14    ella DistribuidoraHá 9 anos no Mercado Livre C...  maquiagem
# 15    Produto Novo“Tolkien é meu mestre” – George R....      livro
# 16    Os meninos vão adorar a barraca dos Vingadores...  brinquedo
# 17    Produto : Boneco do Trunksproduto novo a pront...  brinquedo
# 18    Box Coleção Os Heróis do Olimpo (5 Livros) Est...      livro
# 19    Coleção Kit 18 Miniaturas Super Mario Bros - P...  brinquedo
# 20    KIT COM 2 FIGURE ACTION - GOKU + BARDOCK - DRA...  brinquedo
# 21    Produto NovoSimon tem dezesseis anos e é gay, ...      livro
# 22    Consulte nosso estoque, faça perguntas esclare...       game
# 23    Produto NovoFruto de uma vida inquieta e de um...      livro
# 24    Cola cilios Atelier Paris 15ml original envio ...  maquiagem
# 25    LIVROS LACRADOS PRODUTO NOVOVEJA ABAIXO A DESC...      livro
# 26    kit pinceis Profissional cerdas sinteticas 20 ...  maquiagem
# 27    Oferta Exclusiva MALETASMANIAProduto Original ...  maquiagem
# 28    Base líquida Matte Ruby Rose disponíveis no es...  maquiagem
# 29    Tamanho: 4 - 11 cmMaterial: PVCEspecialidade: ...  brinquedo
# ...                                                 ...        ...
# 2886  Kit nova Caixa12 Carrinhos Patrulha Canina São...  brinquedo
# 2887  PRODUTO PRONTA ENTREGATENHO 8 10 12 14 MM DEIX...  maquiagem
# 2888  Compre com a WOW GAMES*Mais de 14 anos vendend...       game
# 2889  Animais Fantásticos e Onde Habitam Acromântula...      livro
# 2890  Livros Stephen king Novos e Lacrados - It A Co...      livro
# 2891  Rayman® Legends TAMANHO DO ARQUIVO2.1 GBPLATAF...       game
# 2892  CaracteristicasFabricanteHamsbroPersonagemVing...  brinquedo
# 2893  LIVROS USADOS, EM CAPA DURA, EM BOM ESTADO, SE...      livro
# 2894  Produto NovoÉ perto da meia-noite quando a nev...      livro
# 2895  Características:- Marca: Sony- Game: Game Hori...       game
# 2896  BONECO BIG HERO COM 16 CM, ARTICULADO NOS BRAÇ...  brinquedo
# 2897  Meu nome é Bobby Singer. Em vinte e quatro hor...      livro
# 2898  QUEM SOMOS:Personage STORE, a loja virtual que...  brinquedo
# 2899  SHOOPWEB Suer kIT - Palteta Sombra Belle Angel...  maquiagem
# 2900  Boneco dragon ball zTamanho: 12 cmMaterial: Pv...  brinquedo
# 2901  The Last Of Us Psn Ps3 - Dublado Portugues Br ...       game
# 2902  Compras Até 49 Unidades Frete por Carta Regist...  maquiagem
# 2903  Uma jornada no Egito Antigo, o lugar mais mist...       game
# 2904  Amaral IMPORT- Somos lojista estamos no centro...  brinquedo
# 2905  ----------------------Livro novo e lacrado----...      livro
# 2906  As Crônicas De Nárnia - Volume Único Narnia - ...      livro
# 2907  Produto NovoNesta edição de luxo, três das mai...      livro
# 2908  Produto NovoO que é preciso saber sobre este l...      livro
# 2909  HankKing LanneTimeWilson FiskUltronBoomerang S...  brinquedo
# 2910  Tufos Naturais Para Cílios - 8mm, 10 mm, 12 mm...  maquiagem
# 2911  ESTAMOS DISPONIBILIZANDO ENTREGA GARANTIDA ATÉ...  brinquedo
# 2912  WSDGAMES apresenta...PATCH PES 2018/Ps3 - vers...       game
# 2913  Bonecos de 15 a 17 centimetrosFeitos de plásti...  brinquedo
# 2914  A PARTIR DE 3 BASES, FRETE GRÁTIS TODO BRASIL ...  maquiagem
# 2915  Todo o reino de Westeros ao alcance das mãos! ...      livro
#
# [2916 rows x 2 columns]

# %%
number_rows = df_master.shape[0]
traninng_threshold = int(0.40 * number_rows)

# %%
training_df = df_master[['descricao', 'categoria']].iloc[0:traninng_threshold]
testing_df = df_master[['descricao', 'categoria']].iloc[traninng_threshold + 1:-1]

# %%
training_df
# Out:
#                                               descricao  categoria
# 0     MALETA MAQUIAGEM MACRILAN 53 ITENS!ML2-2MConté...  maquiagem
# 1     KIT 3 PERSONAGENS PJ MASKSTamanho: 22 cmPeso: ...  brinquedo
# 2     As laminas em U são perfeitas para fazer fios ...  maquiagem
# 3     Você esta comprando na G4PLAYLEIA TODA DESCRIÇ...       game
# 4     Itens Inclusos:-01 Anel -01 Mascara-01 Lantern...  brinquedo
# 5     Shadow of the Colossus - PS4 - Mídia Física e ...       game
# 6     ATENÇÃO E-book DIGITAL FORMATO PDF ENVIO PELO ...      livro
# 7     PRODUTO PRONTA ENTREGA NO BRASIL              ...  maquiagem
# 8     Paleta de Sombras Be Besweet HB9923 da Ruby Ro...  maquiagem
# 9     Livro Triste Fim de Policarpo QuaresmaTexto in...      livro
# 10    Produto Novo e Físico  Lançado no Brasil origi...      livro
# 11    Coleção Bonecos Dragon Ball Z Super Articulado...  brinquedo
# 12    Você está comprando com a GCM GAMES*Compre com...       game
# 13    Kit 14 Slugterra Slugterraneo Miniaturas Ataca...  brinquedo
# 14    ella DistribuidoraHá 9 anos no Mercado Livre C...  maquiagem
# 15    Produto Novo“Tolkien é meu mestre” – George R....      livro
# 16    Os meninos vão adorar a barraca dos Vingadores...  brinquedo
# 17    Produto : Boneco do Trunksproduto novo a pront...  brinquedo
# 18    Box Coleção Os Heróis do Olimpo (5 Livros) Est...      livro
# 19    Coleção Kit 18 Miniaturas Super Mario Bros - P...  brinquedo
# 20    KIT COM 2 FIGURE ACTION - GOKU + BARDOCK - DRA...  brinquedo
# 21    Produto NovoSimon tem dezesseis anos e é gay, ...      livro
# 22    Consulte nosso estoque, faça perguntas esclare...       game
# 23    Produto NovoFruto de uma vida inquieta e de um...      livro
# 24    Cola cilios Atelier Paris 15ml original envio ...  maquiagem
# 25    LIVROS LACRADOS PRODUTO NOVOVEJA ABAIXO A DESC...      livro
# 26    kit pinceis Profissional cerdas sinteticas 20 ...  maquiagem
# 27    Oferta Exclusiva MALETASMANIAProduto Original ...  maquiagem
# 28    Base líquida Matte Ruby Rose disponíveis no es...  maquiagem
# 29    Tamanho: 4 - 11 cmMaterial: PVCEspecialidade: ...  brinquedo
# ...                                                 ...        ...
# 1136  «« EM ESTOQUE - ENVIO IMEDIATO »»»»» KIT COM 4...  maquiagem
# 1137  10 Bonecos Marvel / Dc / Vingadores / Liga Da ...  brinquedo
# 1138  Basta uma olhadela para desencadear um impulso...      livro
# 1139  KIT C/ 2 Paletas de Sombras NUDE A e B - Jasmy...  maquiagem
# 1140  Bazar MarruaCílios Alongamento Navina Fio a Fi...  maquiagem
# 1141  Maleta Maquiagem Grande Completa Base Mary Kay...  maquiagem
# 1142  24 BONECOS EM MINIATURAS POKÉMON GO DE 2 A 3 C...  brinquedo
# 1143  Delineador em Gel Inglot - Preto 77O Delineado...  maquiagem
# 1144  Especificação:Material: ABS + Componentes elet...  brinquedo
# 1145  Produto Novo e Físico  Às vésperas de seu aniv...      livro
# 1146  Você está comprando com a GCM GAMES*Compre com...       game
# 1147  SHOOPWEBkIT MASTER - Paleta Base + Kit Pinceis...  maquiagem
# 1148  Box Série Fallen - 5 livros - Lauren KateCapa ...      livro
# 1149  Boneco Dragon Ball Z Goku Ssj3 Articulado Goku...  brinquedo
# 1150  VALOR DO PRODUTO: R$ 1,50 (1 UNIDADE)COMO COMP...  maquiagem
# 1151  Kit com 9 personagens da patrulha caninaTamanh...  brinquedo
# 1152  JOGO ORIGINAL. NOVO. LACRADO. PRONTA ENTREGA. ...       game
# 1153  BONECO DA SÉRIE DRAGON BALLPREÇO DA UNIDADEMED...  brinquedo
# 1154  ATENÇÃO!PARA OBTER O FRETE GRÁTIS, SELECIONAR ...      livro
# 1155  Pro Evolution Soccer - Pes 2018 - Xbox 360 Jog...       game
# 1156  Horizon Zero Dawn - Ps4Jogo Original. Novo lac...       game
# 1157  Glitter/Pigmento Fand Makeup Fracionado.Um gli...  maquiagem
# 1158  Produto NovoOutros jeitos de usar a boca é um ...      livro
# 1159  Kit com 20 Personagens de Dragon Ball, Z e GT-...  brinquedo
# 1160                              Aproximadamente 15cm.  brinquedo
# 1161  Produto Novo e Físico  Após um traumático térm...      livro
# 1162          1 unidade de limpador de pincéis Macrilan  maquiagem
# 1163  Assassins Creed Origins - Xbox One - Original ...       game
# 1164  Kit Com 6 Bonecos Heróis De Pijama Pj Masks Di...  brinquedo
# 1165  Descrição do Kit Ninja (Foto) :Duas Kunais Nar...  brinquedo
#
# [1166 rows x 2 columns]

# %%
testing_df
# Out:
#                                               descricao  categoria
# 1167  BB CREAM LATIKA - BEGE CLARO - Clareamento (wh...  maquiagem
# 1168  Áudio: Português BR (Narração Thiago Leifert e...       game
# 1169  Produto NovoUma caixa especial que reúne algun...      livro
# 1170  Organizador De Maquiagem Acrílico 20 Divisória...  maquiagem
# 1171  12 CARRINHOS DA PATRULHA CANINATamanho: aproxi...  brinquedo
# 1172  Base Ruby Rose Preço de Atacado para apenas 1 ...  maquiagem
# 1173  Cílios Tufos para alongamento 3D Navina Bandej...  maquiagem
# 1174  Oferta Exclusiva MALETASMANIAProduto Original ...  maquiagem
# 1175  Produto Novo e Físico  A terra dos meninos pel...      livro
# 1176                              Aproximadamente 15cm.  brinquedo
# 1177  HEROIS MARVEL X DC COMICSMODELO FUNKO POP10 PE...  brinquedo
# 1178  MALETA SEM . ESQUADRÃO COM PRODUTOS VULT COMPL...  maquiagem
# 1179  **Alta intensidade de cor**traçado firme**dura...  maquiagem
# 1180  TOM CLANCY'S RAINBOW SIX SIEGE - XBOX ONE - DI...       game
# 1181  PALETAS NAS CORES  NATURAL, ADORABLE, GLAMOUR,...  maquiagem
# 1182  Produto NovoAo lado de “A Revolução dos Bichos...      livro
# 1183  .Sonic Unleashed Xbox 360 - Mídia Física Lacra...       game
# 1184  Assassins Creed Origins - Xbox One - Original ...       game
# 1185  Compre com a WOW GAMES*Mais de 14 anos vendend...       game
# 1186  NOVA MALETA MAQUIAGEM MACRILANSUPER LANÇAMENTO...  maquiagem
# 1187  Super Oferta!!01-Maleta profissional Grande De...  maquiagem
# 1188  Produto Novo“Extraordinário” é um livro que co...      livro
# 1189  FAR CRY 4TAMANHO: 9 GBÁUDIO, MENUS E LEGENDAS ...       game
# 1190  ***CRIE SEUS POKEMONS***OBS.: Não se tratada d...       game
# 1191  Boneco The Flash LJ (55cm) - Bandeirante - 809...  brinquedo
# 1192  Assassins Creed Origins Edição Limitada | Jogo...       game
# 1193  Boneco dragon ball zTamanho: 12 cmMaterial: Pv...  brinquedo
# 1194  Diferentes gerações do Sonic se encontram para...       game
# 1195  Produto Novo e Físico  Um verão na Itália, uma...      livro
# 1196  Descrição: Lâmina para Micropigmentação/Microb...  maquiagem
# ...                                                 ...        ...
# 2885  ACHOU O MERCADO ENVIOS CARO?CONSULTE O VALOR C...      livro
# 2886  Kit nova Caixa12 Carrinhos Patrulha Canina São...  brinquedo
# 2887  PRODUTO PRONTA ENTREGATENHO 8 10 12 14 MM DEIX...  maquiagem
# 2888  Compre com a WOW GAMES*Mais de 14 anos vendend...       game
# 2889  Animais Fantásticos e Onde Habitam Acromântula...      livro
# 2890  Livros Stephen king Novos e Lacrados - It A Co...      livro
# 2891  Rayman® Legends TAMANHO DO ARQUIVO2.1 GBPLATAF...       game
# 2892  CaracteristicasFabricanteHamsbroPersonagemVing...  brinquedo
# 2893  LIVROS USADOS, EM CAPA DURA, EM BOM ESTADO, SE...      livro
# 2894  Produto NovoÉ perto da meia-noite quando a nev...      livro
# 2895  Características:- Marca: Sony- Game: Game Hori...       game
# 2896  BONECO BIG HERO COM 16 CM, ARTICULADO NOS BRAÇ...  brinquedo
# 2897  Meu nome é Bobby Singer. Em vinte e quatro hor...      livro
# 2898  QUEM SOMOS:Personage STORE, a loja virtual que...  brinquedo
# 2899  SHOOPWEB Suer kIT - Palteta Sombra Belle Angel...  maquiagem
# 2900  Boneco dragon ball zTamanho: 12 cmMaterial: Pv...  brinquedo
# 2901  The Last Of Us Psn Ps3 - Dublado Portugues Br ...       game
# 2902  Compras Até 49 Unidades Frete por Carta Regist...  maquiagem
# 2903  Uma jornada no Egito Antigo, o lugar mais mist...       game
# 2904  Amaral IMPORT- Somos lojista estamos no centro...  brinquedo
# 2905  ----------------------Livro novo e lacrado----...      livro
# 2906  As Crônicas De Nárnia - Volume Único Narnia - ...      livro
# 2907  Produto NovoNesta edição de luxo, três das mai...      livro
# 2908  Produto NovoO que é preciso saber sobre este l...      livro
# 2909  HankKing LanneTimeWilson FiskUltronBoomerang S...  brinquedo
# 2910  Tufos Naturais Para Cílios - 8mm, 10 mm, 12 mm...  maquiagem
# 2911  ESTAMOS DISPONIBILIZANDO ENTREGA GARANTIDA ATÉ...  brinquedo
# 2912  WSDGAMES apresenta...PATCH PES 2018/Ps3 - vers...       game
# 2913  Bonecos de 15 a 17 centimetrosFeitos de plásti...  brinquedo
# 2914  A PARTIR DE 3 BASES, FRETE GRÁTIS TODO BRASIL ...  maquiagem
#
# [1748 rows x 2 columns]

# %% [markdown]
# ## Preparação, treinamento, predição & análise dos dados para solução

# %% [markdown]
# ### *DecisionTreeClassifier* + *CountVectorizer*

# %%
training_docs = training_df["descricao"].values
training_classes = training_df["categoria"].values
testing_docs = testing_df["descricao"].values

# %%
vectorizer = CountVectorizer(analyzer="word")
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = DecisionTreeClassifier()
model.fit(frequency_training_docs, training_classes)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['maquiagem', 'game', 'livro', ..., 'brinquedo', 'brinquedo',
#        'maquiagem'], dtype=object)

# %%
y_true = testing_df["categoria"].values
y_pred = testing_classes

# %%
experiment_1 = f1_score(y_true, y_pred, average=None)
experiment_1
# Out:
# array([0.86104218, 0.89807163, 0.94117647, 0.91155047])

# %% [markdown]
# ### DecisionTreeClassifier + TfidfVectorizer

# %%
training_docs = training_df["descricao"].values
training_classes = training_df["categoria"].values
testing_docs = testing_df["descricao"].values

# %%
vectorizer = TfidfVectorizer(analyzer="word")
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = DecisionTreeClassifier()
model.fit(frequency_training_docs, training_classes)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['maquiagem', 'game', 'livro', ..., 'game', 'brinquedo',
#        'maquiagem'], dtype=object)

# %%
y_true = testing_df["categoria"].values
y_pred = testing_classes

# %%
experiment_2 = f1_score(y_true, y_pred, average=None)
experiment_2
# Out:
# array([0.8369153 , 0.90305445, 0.93535354, 0.8981289 ])

# %% [markdown]
# ### *DecisionTreeClassifier* + (*CountVectorizer* + *TfidfVectorizer*)

# %%
training_docs = training_df["descricao"].values
training_classes = training_df["categoria"].values
testing_docs = testing_df["descricao"].values

# %%
vectorizer = CountVectorizer(analyzer="word", min_df=1)
frequency_training_docs = vectorizer.fit_transform(training_docs)
tf_transformer = TfidfTransformer(use_idf=False).fit(frequency_training_docs)
frequency_training_docs = tf_transformer.transform(frequency_training_docs)
model = DecisionTreeClassifier()
model.fit(frequency_training_docs, training_classes)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
tf_transformer = TfidfTransformer(use_idf=False).fit(frequency_testing_docs)
frequency_testing_docs = tf_transformer.transform(frequency_testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['maquiagem', 'game', 'livro', ..., 'game', 'brinquedo',
#        'maquiagem'], dtype=object)

# %%
y_true = testing_df["categoria"].values
y_pred = testing_classes

# %%
experiment_3 = f1_score(y_true, y_pred, average=None)
experiment_3
# Out:
# array([0.82338308, 0.9170068 , 0.92633703, 0.9047619 ])

# %% [markdown]
# ### *DecisionTreeClassifier* + Unigram

# %%
training_docs = training_df["descricao"].values
training_classes = training_df["categoria"].values
testing_docs = testing_df["descricao"].values

# %%
vectorizer = CountVectorizer(analyzer="word", ngram_range=(1,1))
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = DecisionTreeClassifier()
model.fit(frequency_training_docs, training_classes)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['maquiagem', 'game', 'livro', ..., 'brinquedo', 'brinquedo',
#        'maquiagem'], dtype=object)

# %%
y_true = testing_df["categoria"].values
y_pred = testing_classes

# %%
experiment_4 = f1_score(y_true, y_pred, average=None)
experiment_4
# Out:
# array([0.86240786, 0.91059147, 0.94294294, 0.91213389])

# %% [markdown]
# ### *DecisionTreeClassifier* + Bigram

# %%
training_docs = training_df["descricao"].values
training_classes = training_df["categoria"].values
testing_docs = testing_df["descricao"].values

# %%
vectorizer = CountVectorizer(analyzer="word", ngram_range=(1,2))
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = DecisionTreeClassifier()
model.fit(frequency_training_docs, training_classes)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['maquiagem', 'game', 'livro', ..., 'brinquedo', 'brinquedo',
#        'maquiagem'], dtype=object)

# %%
y_true = testing_df["categoria"].values
y_pred = testing_classes

# %%
experiment_5 = f1_score(y_true, y_pred, average=None)
experiment_5
# Out:
# array([0.85121951, 0.89544236, 0.94534413, 0.90658174])

# %% [markdown]
# ### *DecisionTreeClassifier* + Trigram

# %%
training_docs = training_df["descricao"].values
training_classes = training_df["categoria"].values
testing_docs = testing_df["descricao"].values

# %%
vectorizer = CountVectorizer(analyzer="word", ngram_range=(1,3))
frequency_training_docs = vectorizer.fit_transform(training_docs)
model = DecisionTreeClassifier()
model.fit(frequency_training_docs, training_classes)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
frequency_testing_docs = vectorizer.transform(testing_docs)
testing_classes = model.predict(frequency_testing_docs)

# %%
testing_classes
# Out:
# array(['maquiagem', 'game', 'livro', ..., 'brinquedo', 'brinquedo',
#        'maquiagem'], dtype=object)

# %%
y_true = testing_df["categoria"].values
y_pred = testing_classes

# %%
experiment_6 = f1_score(y_true, y_pred, average=None)
experiment_6
# Out:
# array([0.85929648, 0.90785908, 0.94257426, 0.92016807])

# %% [markdown]
# ## Comparativo das soluções

# %%
experiment_1
# Out:
# array([0.86104218, 0.89807163, 0.94117647, 0.91155047])

# %%
experiment_2
# Out:
# array([0.8369153 , 0.90305445, 0.93535354, 0.8981289 ])

# %%
experiment_3
# Out:
# array([0.82338308, 0.9170068 , 0.92633703, 0.9047619 ])

# %%
experiment_4
# Out:
# array([0.86240786, 0.91059147, 0.94294294, 0.91213389])

# %%
experiment_5
# Out:
# array([0.85121951, 0.89544236, 0.94534413, 0.90658174])

# %%
experiment_6
# Out:
# array([0.85929648, 0.90785908, 0.94257426, 0.92016807])

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(experiment_1,c='b',marker="^",ls='--',label='experiment_1')
ax.plot(experiment_2,c='g',marker=(8,2,0),ls='--',label='experiment_2')
ax.plot(experiment_3,c='k',ls='-',label='experiment_3')
ax.plot(experiment_4,c='r',marker="v",ls='-',label='experiment_4')
ax.plot(experiment_5,c='m',marker="o",ls='--',label='experiment_5')
ax.plot(experiment_6,c='k',marker="+",ls=':',label='experiment_6')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# A partir dos resultados obtidos pelos experimentos, o experimento 4, utilizando o*DecisionTreeClassifier* com *Unigram* (a partir do *CountVectorizer*) foi o que obteve melhor resultado (a partir da métrica F1 Score).
